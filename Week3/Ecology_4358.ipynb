# %%
import sys

result_dic = {}
num = 0

for line in sys.stdin:  # 반복된 입력 받는 방법
    if line == "\n":
        break
    input_x = line.strip()
    num += 1
    if input_x in result_dic.keys():
        result_dic[input_x] += 1
    else:
        result_dic[input_x] = 1

sorted_result_dic = sorted(result_dic.items(), key = lamda x:x[0])

for k, v in sorted_result_dic:
    percentage = round((v / num) * 100, 4)
    print(k, "%4f" %percentage)
