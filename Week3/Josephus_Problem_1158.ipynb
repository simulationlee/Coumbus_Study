# %%
from collections import deque

n, k = map(int, input().strip().split())

result_deq = deque(range(1, n + 1))
result_list = []

for _ in range(n):
    result_deq.rotate(-(k - 1))
    result_list.append(result_deq.popleft())
print("<" + ", ".join(map(str, result_list)) + ">")
# Out:
# 7 3
# <3, 6, 2, 7, 5, 1, 4>
