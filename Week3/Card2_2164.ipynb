# %%
from collections import deque

num = int(input())

result_deq = deque(range(1, num+1))

for _ in range(num-1):
    result_deq.popleft()
    result_deq.append(result_deq.popleft())
print(int(result_deq.pop()))
# Out:
# 6
# 4
